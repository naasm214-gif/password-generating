# %%
##   Queue   (FIFO - First In First Out)
from collections import  deque
queue= deque([10,20,30])
queue.append(40)
print(queue)
queue.pop()
print(queue)
queue.popleft()
print(queue)
queue.appendleft(100)
print(queue)
k=[1,2,3,4,5]
queue.extend(k)
print(queue)
