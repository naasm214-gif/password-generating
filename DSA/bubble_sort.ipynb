# %%
def dubble_sort(arr):
    n=len(arr)
    for i in range(n):
        for j in range(0,n-i-1):
            if arr[j]>arr[j+1]:
                arr[j],arr[j+1]=arr[j+1],arr[j]
    return arr
print(dubble_sort([64,34,25,22,11,90]))
# Out:
# [11, 22, 25, 34, 64, 90]

# %%
def sort_fun(sort):
    a=len(sort)
    for m in range(a):
        for n in range(0,a-m-1):
            if sort[n]>sort[n+1]:
                sort[n],sort[n+1]=sort[n+1],sort[n]
    return sort
u = [10,20,40,90,60,50,70,]
print(sort_fun(u))
type(u)
# Out:
# [10, 20, 40, 50, 60, 70, 90]
# list
